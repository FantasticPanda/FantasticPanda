# %% [markdown]
# <a href="https://colab.research.google.com/github/FantasticPanda/FantasticPanda/blob/main/Copy_of_PANDAS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# There are three kinds ofdata structures i.e
# - series, dataframe and panels
#
#
#
# 1.  SERIES
#
#
# A series is a data structure used to model one-dimensional data, similar to a list in Python. It has a single axis, the index, and a name. A data structure in pure Python can be represented as a dictionary with a list of data points, a dictionary for the actual data, an explicit entry for the corresponding index values, and an entry for the name of the data. The get function can pull items from this data structure based on the index.
#
# The series object is created from a list and has an index column with entries for the index. The index is an axis, and the values of the index are called axis labels.

# %% [markdown]
# It is easy to inspect the index of a series (or data frame), as it is an attribute of the object. The default values for an index are monotonically increasing integers. In some cases, the index can be string-based, with the datatype being object (not string).
#
# The actual data for a series does not have to be numeric or homogeneous. We can insert Python objects into a series, such as Foo classes. The dtype-datatype-of the Series is object (meaning a Python object), which can be good or bad. The object data type is used for strings but also for values that have heterogenous types.
#
# A NaN value is used when pandas determines that a series holds numeric values but cannot find a number to represent an entry. This value stands for Not A Number and is usually ignored in arithmetic operations.
#
# To represent this data in pure Python, use a data structure similar to the one provided, which is a dictionary with a list of data points, an explicit entry for the corresponding index values, and an entry for the name of the data.

# %%
import pandas as pd
import numpy as np

# %%
nan_ser = pd.Series([2, None],index=['Ono', 'Clapton'])
nan_ser
# Out:
# Ono        2.0
# Clapton    NaN
# dtype: float64

# %% [markdown]
# One thing to note is that the type of this series is float64, not int64!
# This is because the only numeric column that supports NaN is the float
# column. When pandas sees numeric data (2) as well as the None, it
# coerced the 2 to a float value
#
# Below is an example of how pandas ignores NaN. The .count method,
# which counts the number of values in a series, disregards NaN. In this case,
# it indicates that the count of items in the Series is one, one for the value
# of 2 at index location Ono, ignoring the NaN value at index location
# Clapton:

# %%
nan_ser.count()
# Out:
# 1

# %%
doctors_series = pd.Series(["DR. Kebaso", "Dr. Tina", "Dr. Teddy"])
doctors_series
# Out:
# 0    DR. Kebaso
# 1      Dr. Tina
# 2     Dr. Teddy
# dtype: object

# %% [markdown]
#  CREATION

# %%
george_dupe = pd.Series([10, 7, 1, 22],
index=['1968', '1969', '1970', '1970'],
name='George Songs')
george_dupe
# Out:
# 1968    10
# 1969     7
# 1970     1
# 1970    22
# Name: George Songs, dtype: int64

# %% [markdown]
# Reading
#
# To read or select the data from a series, one can simply use an index
# operation in combination with the index entry:

# %%
george_dupe['1970']
# Out:
# 1970     1
# 1970    22
# Name: George Songs, dtype: int64

# %% [markdown]
# Updating
#
# To update a value
# for a given index label, the standard index assignment operation works and
# performs the update in-place (in effect mutating the series):

# %%
george_dupe['1973'] = 11
george_dupe['1968'] = 110
george_dupe
# Out:
# 1968    110
# 1969      7
# 1970      1
# 1970     22
# 1973     11
# Name: George Songs, dtype: int64

# %% [markdown]
# Deletion
#
# Deletion is not common in the pandas world. It is more common to use
# filters or masks to create a new series that has only the items that you
# want. However, if you really want to remove entries, you can delete based
# on index entries.
# Recent versions of pandas support the del statement, which deletes
# based on the index:

# %%
del george_dupe['1973']
george_dupe
# Out:
# 1968    110
# 1969      7
# 1970      1
# 1970     22
# Name: George Songs, dtype: int64

# %% [markdown]
# Series Indexing

# %%
george = pd.Series([10, 7],
                  index=['1968', '1969'],
                  name='George Songs')
george
# Out:
# 1968    10
# 1969     7
# Name: George Songs, dtype: int64

# %% [markdown]
#  2. DATA FRAMES
#
#  These data types are two dimensional.
#  A DataFrame represents a rectangular table of data and contains an ordered collection
# of columns, each of which can be a different value type (numeric, string,
# boolean, etc.). The DataFrame has both a row and column index; it can be thought of
# as a dict of Series all sharing the same index. Under the hood, the data is stored as one
# or more two-dimensional blocks rather than a list, dict, or some other collection of
# one-dimensional arrays.
#  A DataFrame, is often used for analytical purposes and is better
# understood when thought of as column oriented, where each column is a
# Series.
#
# There are many ways to construct a DataFrame, though one of the most common is
# from a dict of equal-length lists or NumPy arrays:

# %%
data = {
      'City': ['Nairobi', 'Nakuru', 'Mombasa', 'Kampala', 'Soweto', 'Jinja'],
      'year': [2000, 2001, 2002, 2001, 2002, 2003],
      'population': [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]
    }

frame = pd.DataFrame(data)
frame
# Out:
#       City  year  population
# 0  Nairobi  2000         1.5
# 1   Nakuru  2001         1.7
# 2  Mombasa  2002         3.6
# 3  Kampala  2001         2.4
# 4   Soweto  2002         2.9
# 5    Jinja  2003         3.2

# %% [markdown]
# If you specify a sequence of columns, the DataFrame’s columns will be arranged in
# that order:

# %%
pd.DataFrame(data, columns=['year', 'City', 'population'])
# Out:
#    year     City  population
# 0  2000  Nairobi         1.5
# 1  2001   Nakuru         1.7
# 2  2002  Mombasa         3.6
# 3  2001  Kampala         2.4
# 4  2002   Soweto         2.9
# 5  2003    Jinja         3.2

# %% [markdown]
# RETRIVAL
#
# A column in a DataFrame can be retrieved as a Series either by dict-like notation or
# by attribute:

# %%
p = frame['City']
p
# Out:
# 0    Nairobi
# 1     Nakuru
# 2    Mombasa
# 3    Kampala
# 4     Soweto
# 5      Jinja
# Name: City, dtype: object

# %%
frame.year
# Out:
# 0    2000
# 1    2001
# 2    2002
# 3    2001
# 4    2002
# 5    2003
# Name: year, dtype: int64

# %% [markdown]
# Columns can be modified by assignment. For example, the empty 'debt' column
# could be assigned a scalar value or an array of values:

# %%
frame['debt'] = 16.5

# %%
frame
# Out:
#       City  year  population  debt
# 0  Nairobi  2000         1.5  16.5
# 1   Nakuru  2001         1.7  16.5
# 2  Mombasa  2002         3.6  16.5
# 3  Kampala  2001         2.4  16.5
# 4   Soweto  2002         2.9  16.5
# 5    Jinja  2003         3.2  16.5

# %%
frame['debt'] = np.arange(6.)
frame
# Out:
#       City  year  population  debt
# 0  Nairobi  2000         1.5   0.0
# 1   Nakuru  2001         1.7   1.0
# 2  Mombasa  2002         3.6   2.0
# 3  Kampala  2001         2.4   3.0
# 4   Soweto  2002         2.9   4.0
# 5    Jinja  2003         3.2   5.0

# %% [markdown]
# When you are assigning lists or arrays to a column, the value’s length must match the
# length of the DataFrame. If you assign a Series, its labels will be realigned exactly to
# the DataFrame’s index, inserting missing values in any holes:

# %%
#val = pd.Series([200, 400, 60], index=[2, 4, 5])
val = pd.Series([200, 400, 60, 7, 23, 25])

val
# Out:
# 0    200
# 1    400
# 2     60
# 3      7
# 4     23
# 5     25
# dtype: int64

# %%
frame['debt'] = val
frame
# Out:
#       City  year  population  debt
# 0  Nairobi  2000         1.5   200
# 1   Nakuru  2001         1.7   400
# 2  Mombasa  2002         3.6    60
# 3  Kampala  2001         2.4     7
# 4   Soweto  2002         2.9    23
# 5    Jinja  2003         3.2    25

# %% [markdown]
# Assigning a column that doesn’t exist will create a new column

# %%
frame["Country"] = 0
frame
# Out:
#       City  year  population  debt  Country
# 0  Nairobi  2000         1.5   200        0
# 1   Nakuru  2001         1.7   400        0
# 2  Mombasa  2002         3.6    60        0
# 3  Kampala  2001         2.4     7        0
# 4   Soweto  2002         2.9    23        0
# 5    Jinja  2003         3.2    25        0

# %% [markdown]
# Indexing into a DataFrame is for retrieving one or more columns either with a single
# value or sequence:

# %%
data = pd.DataFrame(np.arange(16).reshape((4, 4)),
    index=['Nairobi', 'Juja', 'Kiambu', 'Mombasa'],
    columns=['one', 'two', 'three', 'four'])
data
# Out:
#          one  two  three  four
# Nairobi    0    1      2     3
# Juja       4    5      6     7
# Kiambu     8    9     10    11
# Mombasa   12   13     14    15

# %%
data['two']
# Out:
# Nairobi     1
# Juja        5
# Kiambu      9
# Mombasa    13
# Name: two, dtype: int64

# %%
data[['three', 'one']]
# Out:
#          three  one
# Nairobi      2    0
# Juja         6    4
# Kiambu      10    8
# Mombasa     14   12

# %% [markdown]
# Indexing like this has a few special cases. First, slicing or selecting data with a boolean
# array:

# %%
data[:4]
# Out:
#          one  two  three  four
# Nairobi    0    1      2     3
# Juja       4    5      6     7
# Kiambu     8    9     10    11
# Mombasa   12   13     14    15

# %%
data[data['three'] > 5]
# data['three'] > 5
# Out:
#          one  two  three  four
# Juja       4    5      6     7
# Kiambu     8    9     10    11
# Mombasa   12   13     14    15

# %% [markdown]
# The row selection syntax data[:2] is provided as a convenience. Passing a single element
# or a list to the [] operator selects columns.
# Another use case is in indexing with a boolean DataFrame, such as one produced by a
# scalar comparison

# %%
data < 5
# Out:
#            one    two  three   four
# Nairobi   True   True   True   True
# Juja      True  False  False  False
# Kiambu   False  False  False  False
# Mombasa  False  False  False  False

# %%
data[data < 5] = 0
data
# Out:
#          one  two  three  four
# Nairobi    0    0      0     0
# Juja       0    5      6     7
# Kiambu     8    9     10    11
# Mombasa   12   13     14    15

# %% [markdown]
# Selection with loc and iloc
#
# For DataFrame label-indexing on the rows, I introduce the special indexing operators
# loc and iloc. They enable you to select a subset of the rows and columns from a
# DataFrame with NumPy-like notation using either axis labels (loc) or integers
# (iloc).
# As a preliminary example, let’s select a single row and multiple columns by label:

# %%
data.loc['Juja', ['two', 'three']]
# Out:
# two      5
# three    6
# Name: Juja, dtype: int64

# %%
data.loc["Nairobi"]
# Out:
# one      0
# two      1
# three    2
# four     3
# Name: Nairobi, dtype: int64

# %% [markdown]
# We’ll then perform some similar selections with integers using iloc:

# %%
data.iloc[2, [3, 0, 1]]
# Out:
# four    11
# one      8
# two      9
# Name: Kiambu, dtype: int64

# %%
data.iloc[2]
# Out:
# one       8
# two       9
# three    10
# four     11
# Name: Kiambu, dtype: int64

# %%
data.iloc[[1, 2], [3, 0, 1]]
# Out:
#         four  one  two
# Juja       7    0    5
# Kiambu    11    8    9

# %% [markdown]
# Both indexing functions work with slices in addition to single labels or lists of labels:

# %%
data.loc[:'Kiambu']
# Out:
#          one  two  three  four
# Nairobi    0    1      2     3
# Juja       4    5      6     7
# Kiambu     8    9     10    11

# %%
data.iloc[:, :3][data.three > 5]
# Out:
#          one  two  three
# Juja       4    5      6
# Kiambu     8    9     10
# Mombasa   12   13     14

# %% [markdown]
# Type            Notes
#
# df[val]
#
#  Select single column or sequence of columns from the DataFrame; special case
# conveniences: boolean array (filter rows), slice (slice rows), or boolean DataFrame
# (set values based on some criterion)
# df.loc[val]
#
#  Selects single row or subset of rows from the DataFrame by label
#
# df.loc[:, val]
#
# Selects single column or subset of columns by label
#
# df.loc[val1, val2]
#
#  Select both rows and columns by label
#
# df.iloc[where]
#
#  Selects single row or subset of rows from the DataFrame by integer position
#
#  df.iloc[:, where]
#
#  Selects single column or subset of columns by integer position
#
# df.iloc[where_i, where_j]
#
#  Select both rows and columns by integer position
#
# df.at[label_i, label_j]
#
#  Select a single scalar value by row and column label
#
# df.iat[i, j]
#
#  Select a single scalar value by row and column position (integers)
# reindex method Select either rows or columns by labels
# get_value, set_value methods Select single value by row and column label

# %% [markdown]
# Integer Indexes
